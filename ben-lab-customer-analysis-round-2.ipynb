# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('/Users/ben/Iron-ben/lab-customer-analysis-round-2/files_for_lab/csv_files/marketing_customer_analysis.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df1 = pd.read_csv('/Users/ben/Iron-ben/lab-customer-analysis-round-2/files_for_lab/csv_files/marketing_customer_analysis.csv')
#
# NameError: name 'pd' is not defined

# %%
df1
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# ...

# %%
df1 = pd.DataFrame(df1)

# %%
# Show the dataframe shape.

# %%
df1.shape
# Out:
# (10910, 26)

# %%
# Standardize header names.

# %%
df1.columns = map(str.lower, df1.columns)
df1
# Out:
#        unnamed: 0 customer       state  customer lifetime value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        coverage education effective to date employmentstatus gender  ...  \
# ...

# %%
# Check and deal with NaN values.

# %%
# fist I want to check that the names of the header are Standardize

# %%
df1
# Out:
#        unnamed: 0 customer       state  customer lifetime value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        coverage education effective to date employmentstatus gender  ...  \
# ...

# %%
# Now I will do the operation of looking for NaN

# %%
df1.isna().any()
# Out:
# unnamed: 0                       False
# customer                         False
# state                             True
# customer lifetime value          False
# response                          True
# coverage                         False
# education                        False
# effective to date                False
# employmentstatus                 False
# gender                           False
# income                           False
# location code                    False
# marital status                   False
# monthly premium auto             False
# months since last claim           True
# months since policy inception    False
# number of open complaints         True
# number of policies               False
# policy type                      False
# policy                           False
# renew offer type                 False
# sales channel                    False
# total claim amount               False
# vehicle class                     True
# ...

# %%
# with this formula we can see that the ones that are True are the ones that hava NaN

# %%
# But I wan to be able to see the amount of NaN that we have in each column's so for that we will use this formula:

# %%
df1.isna().sum()
# Out:
# unnamed: 0                          0
# customer                            0
# state                             631
# customer lifetime value             0
# response                          631
# coverage                            0
# education                           0
# effective to date                   0
# employmentstatus                    0
# gender                              0
# income                              0
# location code                       0
# marital status                      0
# monthly premium auto                0
# months since last claim           633
# months since policy inception       0
# number of open complaints         633
# number of policies                  0
# policy type                         0
# policy                              0
# renew offer type                    0
# sales channel                       0
# total claim amount                  0
# vehicle class                     622
# vehicle size                      622
# ...

# %%
# Now that I have the series with the number of Nan I will delete those NaN

# %%
df1
# Out:
#        unnamed: 0 customer       state  customer lifetime value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        coverage education effective to date employmentstatus gender  ...  \
# ...

# %%
df1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df1
#
# NameError: name 'df1' is not defined

# %%
df1.dropna()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df1.dropna()
#
# NameError: name 'df1' is not defined

# %%
#Which columns are numerical?

# %%
df1= df1.select_dtypes(include=['number']).columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df1= df1.select_dtypes(include=['number']).columns
#
# NameError: name 'df1' is not defined

# %%
df1.fillna("non available")
# Out:
#        unnamed: 0 customer          state  customer lifetime value  \
# 0               0  DK49336        Arizona              4809.216960
# 1               1  KX64629     California              2228.525238
# 2               2  LZ68649     Washington             14947.917300
# 3               3  XL78013         Oregon             22332.439460
# 4               4  QA50777         Oregon              9025.067525
# ...           ...      ...            ...                      ...
# 10905       10905  FE99816         Nevada             15563.369440
# 10906       10906  KX53892         Oregon              5259.444853
# 10907       10907  TL39050        Arizona             23893.304100
# 10908       10908  WA60547     California             11971.977650
# 10909       10909  IV32877  non available              6857.519928
#
#             response  coverage education effective to date employmentstatus  \
# 0                 No     Basic   College           2/18/11         Employed
# ...

# %%
pd.dropna(non available)
# Out:
#   Cell In[79], line 1
#     pd.dropna(non available)
#               ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
df1.isna().any()
# Out:
# False

# %%
df1.isna().sum()
# Out:
# 0

# %%
# # Which columns are numerical?

# %%
df1 = df1.select_dtypes(include=['number']).columns

# %%
df1
# Out:
# Index(['unnamed: 0', 'customer lifetime value', 'income',
#        'monthly premium auto', 'months since last claim',
#        'months since policy inception', 'number of open complaints',
#        'number of policies', 'total claim amount'],
#       dtype='object')

# %%
# Out:
# Index(['unnamed: 0', 'customer lifetime value', 'income',
#        'monthly premium auto', 'months since last claim',
#        'months since policy inception', 'number of open complaints',
#        'number of policies', 'total claim amount'],
#       dtype='object')

# %%
df1
# Out:
# Index(['unnamed: 0', 'customer lifetime value', 'income',
#        'monthly premium auto', 'months since last claim',
#        'months since policy inception', 'number of open complaints',
#        'number of policies', 'total claim amount'],
#       dtype='object')

# %%
# Which columns are categorical?

# %%
df1 = df1.select_dtype(include=["category"]).colums

# %%
df1 = df1.select_dtypes(include=['category']).columns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 df1 = df1.select_dtypes(include=['category']).columns
#
# AttributeError: 'Index' object has no attribute 'select_dtypes'

# %%
# Check and deal with NaN values.

# %%
df1
# Out:
# Index(['unnamed: 0', 'customer lifetime value', 'income',
#        'monthly premium auto', 'months since last claim',
#        'months since policy inception', 'number of open complaints',
#        'number of policies', 'total claim amount'],
#       dtype='object')

# %%
df1.isna().any()
# Out:
# False

# %%
df1.isna().sum()
# Out:
# 0
