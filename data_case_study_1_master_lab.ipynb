# %%
import pandas as pd

# %%
df1 = pd.read_excel("file1.xlsx")

# %%
df1
# Out:
#       CONTROLN STATE GENDER      HV1  IC1    IC4  HVP1    IC5  POBC1  POBC2  \
# 0        44060    FL      M   AAA896  392  520.0     7  21975      6     16
# 1        96093    IL      M      537  365  473.0     0  19387      1     89
# 2        43333    FL      F      725  301  436.0     3  18837     11     17
# 3        21885    NC      M  AAA1095  401  413.0     7  14014      1     74
# 4       190108    FL      F      995  252  348.0     0  17991      5      6
# ...        ...   ...    ...      ...  ...    ...   ...    ...    ...    ...
# 1002    114721    OK    NaN     1040  472  656.0     0  26962      2     56
# 1003    149152    CA      M     4507  842  962.0    95  54642     17     50
# 1004       959    IA      F      586  349  465.0     1  15304      1     77
# 1005    179563    WA   male      842  420  494.0     2  12894     41     24
# 1006     41243    FL      F      556  246  330.0     0  10272      2     56
#
#          IC2  IC3    AVGGIFT
# ...

# %%
import pandas as pd

# %%
df2 = pd.read_excel("file2.xlsx")

# %%
df2
# Out:
#       CONTROLN STATE   GENDER   HV1  IC1  IC4  HVP1    IC5  POBC1  POBC2  IC2  \
# 0       190579    CA        M  3200  310  343    83  17224     31     32  311
# 1        42997    FL        F  1567  392  409    27  18631      4     10  391
# 2       132896    OR        F   953  319  455     1  15729      3     45  379
# 3       120189    TX        M   492  244  301     3  10818      0     92  260
# 4       138829    AZ  feamale   847  185  308     0  11582      3     20  238
# ...        ...   ...      ...   ...  ...  ...   ...    ...    ...    ...  ...
# 1010    161838    CA        F  1953  304  380    47  13811     25     43  353
# 1011    161838    CA        F  1953  304  380    47  13811     25     43  353
# 1012    138311    AZ   Female  1708  437  684    36  29098      7     19  586
# 1013    123469    TX        M   561  493  540     1  16623      5     68  529
# 1014    135341    AZ   Female   700  205  295     0  12713      9     12  221
#
#       IC3    AVGGIFT
# ...

# %%
import pandas as pd

# %%
df3 = pd.read_excel("file3.xlsx")

# %%
df3
# Out:
#      CONTROLN      STATE  GENDER   HV1  IC1  IC4  HVP1    IC5  POBC1  POBC2  \
# 0      119966         TX       F   321  225  281     0   9372      3     68
# 1      152470         CA       F  5725  610  807    97  53158     13     22
# 2       48527         AL    Male   931  407  496     0  17743      0     65
# 3      171528         CA       F  1895  317  471    46  17431     10     62
# 4       50122  Tennessee       F   715  318  370     2  12416      0     75
# ..        ...        ...     ...   ...  ...  ...   ...    ...    ...    ...
# 995    179863         WA    male  1253  325  447     7  15635     12     57
# 996     87395         MT  female   842  264  388     3  15084      2     50
# 997     86779         ND       F   331  165  266     0   9324      1     61
# 998     25214         NC  female  1823  544  567    43  21265      1     62
# 999     79641         WI       F  1244  672  776    25  25036      1     64
#
#      IC2  IC3    AVGGIFT
# 0    264  243   8.058824
# ...

# %%
# Data Shape

# %%
>>> df1 = pd.DataFrame(df1)
>>> df1.shape
# Out:
# (1007, 13)

# %%
>>> df2 = pd.DataFrame(df2)
>>> df2.shape
# Out:
# (1015, 13)

# %%
>>> df3 = pd.DataFrame(df3)
>>> df3.shape
# Out:
# (1000, 13)

# %%
# Standardize header names.

# %%
df1.columns = map(str.lower, df1.columns)
df1
# Out:
#       controln state gender      hv1  ic1    ic4  hvp1    ic5  pobc1  pobc2  \
# 0        44060    FL      M   AAA896  392  520.0     7  21975      6     16
# 1        96093    IL      M      537  365  473.0     0  19387      1     89
# 2        43333    FL      F      725  301  436.0     3  18837     11     17
# 3        21885    NC      M  AAA1095  401  413.0     7  14014      1     74
# 4       190108    FL      F      995  252  348.0     0  17991      5      6
# ...        ...   ...    ...      ...  ...    ...   ...    ...    ...    ...
# 1002    114721    OK    NaN     1040  472  656.0     0  26962      2     56
# 1003    149152    CA      M     4507  842  962.0    95  54642     17     50
# 1004       959    IA      F      586  349  465.0     1  15304      1     77
# 1005    179563    WA   male      842  420  494.0     2  12894     41     24
# 1006     41243    FL      F      556  246  330.0     0  10272      2     56
#
#          ic2  ic3    avggift
# ...

# %%
# Rearrange the columns in the dataframe as needed

# %%
df1 = pd.DataFrame(df1=[[1, 2, 3], [4, 5, 6]], columns=['controln', 'state', 'gender'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 df1 = pd.DataFrame(df1=[[1, 2, 3], [4, 5, 6]], columns=['controln', 'state', 'gender'])
#
# TypeError: DataFrame.__init__() got an unexpected keyword argument 'df1'

# %%
# Concatenate the three dataframes

# %%
data123 = pd.concat([df1, df2, df3], axis=1)

# %%
data123
# Out:
#         A    B    C  CONTROLN STATE   GENDER   HV1  IC1  IC4  HVP1  ...  \
# 0     1.0  2.0  3.0    190579    CA        M  3200  310  343    83  ...
# 1     4.0  5.0  6.0     42997    FL        F  1567  392  409    27  ...
# 2     NaN  NaN  NaN    132896    OR        F   953  319  455     1  ...
# 3     NaN  NaN  NaN    120189    TX        M   492  244  301     3  ...
# 4     NaN  NaN  NaN    138829    AZ  feamale   847  185  308     0  ...
# ...   ...  ...  ...       ...   ...      ...   ...  ...  ...   ...  ...
# 1010  NaN  NaN  NaN    161838    CA        F  1953  304  380    47  ...
# 1011  NaN  NaN  NaN    161838    CA        F  1953  304  380    47  ...
# 1012  NaN  NaN  NaN    138311    AZ   Female  1708  437  684    36  ...
# 1013  NaN  NaN  NaN    123469    TX        M   561  493  540     1  ...
# 1014  NaN  NaN  NaN    135341    AZ   Female   700  205  295     0  ...
#
#          HV1    IC1    IC4  HVP1      IC5  POBC1  POBC2    IC2    IC3  \
# ...

# %%
# Which columns are numerical?

# %%
data123 = data123.select_dtypes(include=['number']).columns

# %%
data123
# Out:
# Index(['A', 'B', 'C', 'CONTROLN', 'HV1', 'IC1', 'IC4', 'HVP1', 'IC5', 'POBC1',
#        'POBC2', 'IC2', 'IC3', 'AVGGIFT', 'CONTROLN', 'HV1', 'IC1', 'IC4',
#        'HVP1', 'IC5', 'POBC1', 'POBC2', 'IC2', 'IC3', 'AVGGIFT'],
#       dtype='object')

# %%
# Which columns are categorical?

# %%
data123 = pd.concat([df1, df2, df3], axis=1)

# %%
data123
# Out:
#         A    B    C  CONTROLN STATE   GENDER   HV1  IC1  IC4  HVP1  ...  \
# 0     1.0  2.0  3.0    190579    CA        M  3200  310  343    83  ...
# 1     4.0  5.0  6.0     42997    FL        F  1567  392  409    27  ...
# 2     NaN  NaN  NaN    132896    OR        F   953  319  455     1  ...
# 3     NaN  NaN  NaN    120189    TX        M   492  244  301     3  ...
# 4     NaN  NaN  NaN    138829    AZ  feamale   847  185  308     0  ...
# ...   ...  ...  ...       ...   ...      ...   ...  ...  ...   ...  ...
# 1010  NaN  NaN  NaN    161838    CA        F  1953  304  380    47  ...
# 1011  NaN  NaN  NaN    161838    CA        F  1953  304  380    47  ...
# 1012  NaN  NaN  NaN    138311    AZ   Female  1708  437  684    36  ...
# 1013  NaN  NaN  NaN    123469    TX        M   561  493  540     1  ...
# 1014  NaN  NaN  NaN    135341    AZ   Female   700  205  295     0  ...
#
#          HV1    IC1    IC4  HVP1      IC5  POBC1  POBC2    IC2    IC3  \
# ...

# %%
data123 = data123.select_dtypes(include=['category']).columns

# %%
data123
# Out:
# Index([], dtype='object')

# %%
# Delete the column education and the number of open complaints from the dataframe.
# I can not do this last part of the exercises' cos in the dataframe there is no column of "education"
